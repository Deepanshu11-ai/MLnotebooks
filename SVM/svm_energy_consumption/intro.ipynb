# %% [markdown]
# **🚀 PROJECT 2: Energy Consumption Prediction using SVM Regression**

# %% [markdown]
# 🧠 Project Idea (simple but powerful)
# 🎯 Goal
#
# Predict electricity consumption based on environmental and usage factors using SVM Regression.
#
# 📥 Inputs (features)
#
# You can start with 2–3 features (keep it interpretable):
#
# Temperature
#
# Humidity
#
# Hours_of_Usage
#
# 📤 Output (label)
#
# Energy_Consumption (continuous → regression)

# %% [markdown]
# 📊 Why SVM Regression fits PERFECTLY here
#
# Relationship is not perfectly linear
#
# Noise exists (human usage, weather)
#
# SVM handles:
#
# outliers
#
# noise
#
# non-linear patterns (later with kernels)
#
# This makes it better than plain linear regression.
