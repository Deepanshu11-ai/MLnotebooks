# %%
corpus="hello welocme to the world of python programming. where i am doing NLP tasks and having fun."

# %%
print(corpus)
# Out:
# hello welocme to the world of python programming. where i am doing NLP tasks and having fun.

# %%
#tokenize 
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')  # Download the punkt tokenizer models
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/deepanshus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/deepanshus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/deepanshus/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
nltk.data.path.append('/Library/Frameworks/Python.framework/Versions/3.14/lib/nltk_data')
from nltk.tokenize import sent_tokenize
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
#tokenize words
from nltk.tokenize import word_tokenize
words=word_tokenize(corpus)
print(words)
# Out:
# ['hello', 'welocme', 'to', 'the', 'world', 'of', 'python', 'programming', '.', 'where', 'i', 'am', 'doing', 'NLP', 'tasks', 'and', 'having', 'fun', '.']
